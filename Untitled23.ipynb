# %% [markdown]
# <a href="https://colab.research.google.com/github/rifqyalifpratama/Tugas1-Data-Wrangling/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/Gaming and Mental Health.csv')

# %%
print("--- 5 DATA TERATAS (head) ---")
display(df.head())

print("\n--- INFORMASI DATASET (info) ---")
df.info()

print("\n--- DIMENSI DATASET (shape) ---")
print(f"Dataset ini memiliki {df.shape[0]} baris dan {df.shape[1]} kolom.")
# Out:
# --- 5 DATA TERATAS (head) ---
#   record_id  age  gender  daily_gaming_hours     game_genre    primary_game  \
# 0    GD0001   17    Male                11.1   Mobile Games  Clash of Clans
# 1    GD0002   21    Male                 3.0           MOBA          Dota 2
# 2    GD0003   23    Male                 7.6            FPS           CS:GO
# 3    GD0004   20  Female                 7.2            RPG          Skyrim
# 4    GD0005   18    Male                 6.8  Battle Royale    Apex Legends
#
#   gaming_platform  sleep_hours sleep_quality sleep_disruption_frequency  ...  \
# 0              PC          3.7     Very Poor                  Sometimes  ...
# 1              PC          7.2          Fair                     Rarely  ...
# 2  Multi-platform          4.4          Fair                      Often  ...
# 3  Multi-platform          5.1          Fair                      Often  ...
# 4              PC          3.4          Poor                      Never  ...
#
# ...

# %%
json_manual_gaming = [
    {
        "Game": "Skyrim",
        "Hours_Per_Week": 15,
        "Age": 21,
        "Gender": "Male",
        "GAD_T": 5
    },
    {
        "Game": "League of Legends",
        "Hours_Per_Week": 30,
        "Age": 19,
        "Gender": "Female",
        "GAD_T": 12
    },
    {
        "Game": "Starcraft 2",
        "Hours_Per_Week": 10,
        "Age": 25,
        "Gender": "Male",
        "GAD_T": 3
    }
]

# %%
import json
from google.colab import files

print("\n--- Contoh Struktur JSON Manual yang Saya Susun ---")
print(json.dumps(json_manual_gaming, indent=4))

# Konversi sampel JSON di atas menjadi file CSV baru
df_final = pd.DataFrame(json_manual_gaming)
df_final.to_csv('/content/Gaming and Mental Health.csv', index=False)

print("\nSelesai! File 'hasil_konversi_gaming.csv' sudah berhasil dibuat.")
print("\nSedang mengunduh file hasil konversi...")
files.download('/content/Gaming and Mental Health.csv')
# Out:
# --- Contoh Struktur JSON Manual yang Saya Susun ---
# [
#     {
#         "Game": "Skyrim",
#         "Hours_Per_Week": 15,
#         "Age": 21,
#         "Gender": "Male",
#         "GAD_T": 5
#     },
#     {
#         "Game": "League of Legends",
#         "Hours_Per_Week": 30,
#         "Age": 19,
#         "Gender": "Female",
#         "GAD_T": 12
#     },
#     {
#         "Game": "Starcraft 2",
#         "Hours_Per_Week": 10,
#         "Age": 25,
#         "Gender": "Male",
#         "GAD_T": 3
#     }
# ]
#
# Selesai! File 'hasil_konversi_gaming.csv' sudah berhasil dibuat.
#
# Sedang mengunduh file hasil konversi...
